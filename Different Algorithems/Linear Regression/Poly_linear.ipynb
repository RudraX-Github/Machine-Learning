# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,SGDRegressor
from sklearn.preprocessing import PolynomialFeatures,StandardScaler
from sklearn.metrics import r2_score
from sklearn.pipeline import Pipeline

# %%
path = r'D:\RNW\Project\Simple Linear Regression\Heart_deases-Model\Myocardial_infarction_complications.csv'
#reading the dataset
df = pd.read_csv(path)

#displaying the first 5 rows of the dataset 
# df.head()

# %%
X = df.iloc[:,1:4]
y = df.iloc[:,-1]

# %%
X
# Out:
#       AGE  SEX  INF_ANAM
# 0      77    1         2
# 1      55    1         1
# 2      52    1         0
# 3      68    0         0
# 4      60    1         0
# ...   ...  ...       ...
# 1695   77    0         0
# 1696   70    0         0
# 1697   55    1         3
# 1698   79    0         2
# 1699   63    1         2
#
# [1700 rows x 3 columns]

# %%
X.isna().sum()
# Out:
# AGE         0
# SEX         0
# INF_ANAM    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
# print("MAE",mean_absolute_error(y_test,y_pred))
# print("MSE",mean_squared_error(y_test,y_pred))
print("R2 score",r2_score(y_test,y_pred))
# Out:
# R2 score 0.03814229843212924

# %%
# Applying Polynomial Linear Regression
# degree 2
poly = PolynomialFeatures(degree=2,include_bias=True)

X_train_trans = poly.fit_transform(X_train)
X_test_trans = poly.transform(X_test)

# %%
lr = LinearRegression()
lr.fit(X_train_trans,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test_trans)

# %%
y_pred
# Out:
# array([0.65251802, 0.31155618, 0.52853775, 0.55518685, 0.57050834,
#        0.67713829, 0.26211899, 0.47297679, 0.34775547, 0.28086657,
#        0.60223177, 0.51792235, 0.83340125, 0.3772572 , 0.67713829,
#        0.57581831, 0.4122686 , 0.37209509, 0.70604562, 0.63539579,
#        0.52695394, 0.4487206 , 0.63323004, 0.36029172, 0.39717963,
#        0.46748682, 0.55664909, 0.76281457, 0.54022551, 0.64962668,
#        0.60223177, 0.92077521, 0.32744121, 0.4122686 , 0.31155618,
#        0.52594639, 0.65251802, 0.72460846, 0.56672018, 0.23753326,
#        0.72460846, 0.14902744, 0.84354858, 0.67142367, 0.57751417,
#        0.58618998, 0.69768512, 0.55518685, 0.36029172, 0.23753326,
#        0.70097748, 0.22380913, 0.63058198, 0.54022551, 0.78245784,
#        0.85743312, 0.73614414, 0.93806473, 0.59941746, 0.58764729,
#        1.0925899 , 0.56668183, 0.34368639, 0.32744121, 0.4487206 ,
#        0.2960313 , 1.12032492, 0.50609972, 0.31155618, 0.04560163,
#        0.26606198, 0.72460846, 0.67000041, 0.21044514, 0.70097748,
#        0.89004968, 0.31155618, 0.60893456, 0.31810795, 0.2328474 ,
#        0.93004497, 0.28086657, 0.1974413 , 0.27240566, 0.60223177,
#        0.28343412, 0.06948688, 0.23753326, 0.47297679, 0.47082104,
#        0.92077521, 0.51792235, 0.51138327, 0.57124498, 0.74353144,
#        0.48921667, 0.60223177, 0.64962668, 0.93004497, 0.23753326,
#        0.63539579, 0.21044514, 0.16059068, 0.61298001, 0.21044514,
#        0.46748682, 0.63238476, 0.23753326, 0.21513375, 0.28086657,
#        0.26606198, 0.34775547, 0.12698141, 0.60223177, 0.23753326,
#        0.54009721, 0.50186701, 0.31155618, 0.41161876, 0.34368639,
#        0.38310064, 0.42641804, 0.6186337 , 0.4866132 , 0.72077313,
#        0.4122686 , 0.36029172, 1.00612382, 0.22380913, 0.4487206 ,
#        0.52562432, 0.86463245, 0.25161755, 0.80246127, 0.2960313 ,
#        0.54615321, 0.4122686 , 0.4487206 , 0.65251802, 0.93004497,
